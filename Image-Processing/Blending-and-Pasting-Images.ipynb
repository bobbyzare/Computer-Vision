# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>
#
# # Blending and Pasting Images
#
# For some computer vision systems, we'll want to be able to post our own image on top of an already existing image or video. We may also want to blend images, maybe we want to have a "highlight" effect instead of just a solid box or empty rectangle.
#
# Let's explore what is commonly known as **Arithmetic Image Operations** with OpenCV. These are referred to as Arithmetic Operations because OpenCV is simply performing some common math with the pixels for the final effect. We'll see a bit of this in our code.
#
# ## Blending Images
#
# Blending Images is actually quite simple, let's look at a simple example.

# %% [markdown]
# ## BLENDING AND PASTING IMAGE

# %%
import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
## blending images of the same size

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.8,src2=img2,beta=0.2,gamma=0)

# %%
plt.imshow(blended)

# %%
## overlaying small image on top of large image (no blending)
## numpy reassignment

# %%
img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img2)

# %%
plt.imshow(img1)

# %%
large_img = img1
small_img = img2

# %%
x_offset = 0 # x point on the large image
y_offset = 0 # y point on the large image

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
small_img.shape
# Out:
# (600, 600, 3)

# %%
large_img[y_offset:y_end,x_offset:x_end] = small_img

# %%
plt.imshow(large_img)

# %% [markdown]
# ## BLENDING AND PASTING IMAGE  - MASKING

# %%
img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img1)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
x_offset = 934 - 600 # x point on the large image
y_offset = 1401 - 600 # y point on the large image

# %%
img2.shape
# Out:
# (600, 600, 3)

# %%
rows,colums,channels = img2.shape

# %%
rows
# Out:
# 600

# %%
colums
# Out:
# 600

# %%
channels
# Out:
# 3

# %%
roi = img1[y_offset:1401,x_offset:934]

# %%
plt.imshow(roi)

# %%
img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(img2gray,cmap = "gray")

# %%
mask_inv = cv2.bitwise_not(img2gray)

# %%
plt.imshow(mask_inv,cmap = "gray")

# %%
mask_inv.shape
# Out:
# (600, 600)

# %%
import numpy as np

# %%
White_background = np.full(img2.shape,255,dtype=np.int64)

# %%
White_background.shape
# Out:
# (600, 600, 3)

# %%
bk = cv2.bitwise_or(White_background,White_background,mask=mask_inv)

# %%
bk.shape
# Out:
# (600, 600, 3)

# %%
plt.imshow(bk)

# %%
fg = cv2.bitwise_or(img2,img2,mask= mask_inv)

# %%
plt.imshow(fg)

# %%
final_roi = cv2.bitwise_or(roi,fg)

# %%
plt.imshow(final_roi)

# %%
large_img = img1
small_img = final_roi

# %%
x_offset = 934 - 600 # x point on the large image
y_offset = 1401 - 600 # y point on the large image

# %%
x_end = x_offset+small_img.shape[1]
y_end = y_offset+small_img.shape[0]

# %%
large_img[y_offset:y_end,x_offset:x_end ] = small_img

# %%
plt.imshow(large_img)

# %%
## BLENDING AND PASTING IMAGE

import cv2

import matplotlib.pyplot as plt
# %matplotlib inline

img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)    
                  

plt.imshow(img1)

plt.imshow(img2)

img1.shape

img2.shape

## blending images of the same size

img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

plt.imshow(img1)

plt.imshow(img2)

blended = cv2.addWeighted(src1=img1,alpha=0.8,src2=img2,beta=0.2,gamma=0)

plt.imshow(blended)

## overlaying small image on top of large image (no blending)
## numpy reassignment

img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)    

img2 = cv2.resize(img2,(600,600))

plt.imshow(img2)

plt.imshow(img1)

large_img = img1
small_img = img2

x_offset = 0 # x point on the large image
y_offset = 0 # y point on the large image

x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

small_img.shape

large_img[y_offset:y_end,x_offset:x_end] = small_img

plt.imshow(large_img)

## BLENDING AND PASTING IMAGE PART 2 -MASKING

img1 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)   
                  
img2 = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/watermark_no_copy.png")
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)    

img2 = cv2.resize(img2,(600,600))

plt.imshow(img1)

img1.shape

x_offset = 934 - 600 # x point on the large image
y_offset = 1401 - 600 # y point on the large image 

img2.shape

rows,colums,channels = img2.shape

rows

colums

channels

roi = img1[y_offset:1401,x_offset:934]

plt.imshow(roi)

img2gray = cv2.cvtColor(img2,cv2.COLOR_RGB2GRAY)

plt.imshow(img2gray,cmap = "gray")

mask_inv = cv2.bitwise_not(img2gray)

plt.imshow(mask_inv,cmap = "gray")

mask_inv.shape

import numpy as np

White_background = np.full(img2.shape,255,dtype=np.int64)

White_background.shape

bk = cv2.bitwise_or(White_background,White_background,mask=mask_inv)

bk.shape

plt.imshow(bk)

fg = cv2.bitwise_or(img2,img2,mask= mask_inv)

plt.imshow(fg)

final_roi = cv2.bitwise_or(roi,fg)

plt.imshow(final_roi)

large_img = img1
small_img = final_roi

x_offset = 934 - 600 # x point on the large image
y_offset = 1401 - 600 # y point on the large image 

x_end = x_offset+small_img.shape[1]
y_end = y_offset+small_img.shape[0]

large_img[y_offset:y_end,x_offset:x_end ] = small_img

plt.imshow(large_img)
