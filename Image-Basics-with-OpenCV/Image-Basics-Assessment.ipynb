# %% [markdown]
# # Image Basics Assessment

# %%
import cv2
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %% [markdown]
# #### TASK: Flip the image upside down and display it in the notebook.

# %%
flip_img = cv2.flip(fix_img,0)

# %%
plt.imshow(flip_img)

# %%
new_img = fix_img.copy()
cv2.rectangle(new_img,pt1=(150,750),pt2=(650,300),color=(255,0,0),thickness=5)
# Out:
# array([[[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        [[250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249],
#         ...,
#         [250, 248, 249],
#         [250, 248, 249],
#         [250, 248, 249]],
#
#        ...,
#
#        [[ 50,  40,  39],
#         [ 51,  39,  39],
#         [ 52,  38,  38],
#         ...,
#         [ 73,  80,  86],
#         [ 72,  77,  81],
#         [ 70,  75,  79]],
#
#        [[ 51,  41,  40],
#         [ 52,  40,  40],
#         [ 52,  38,  38],
#         ...,
#         [ 75,  82,  88],
#         [ 73,  78,  84],
#         [ 70,  75,  79]],
#
#        [[ 52,  42,  40],
#         [ 51,  40,  38],
#         [ 53,  39,  39],
# ...

# %%
plt.imshow(new_img)

# %% [markdown]
# #### TASK: Draw a BLUE TRIANGLE in the middle of the image. The size and angle is up to you, but it should be a triangle (three sides) in any orientation.

# %%
vertices = np.array([[250,700],[425,400],[600,700]],np.int32)

# %% [raw]
# vertices.shape

# %%
pts = vertices.reshape((-1,1,2))

# %% [raw]
# pts.shape

# %%
cv2.polylines(fix_img,[pts],isClosed= True,color=(0,0,255),thickness=20)
plt.imshow(fix_img)

# %%
cv2.fillPoly(fix_img,[pts],color=(0,0,255))
plt.imshow(fix_img)

# %%
import cv2
import numpy as np


#function
def draw_circle(event,x,y,flags,param):
    
     if event == cv2.EVENT_RBUTTONDOWN:
        cv2.circle(img,(x,y),200,(0,0,255),10)
        
  


 #show the function


#read the image
img = cv2.imread("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")

cv2.namedWindow("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg")

cv2.setMouseCallback("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg",draw_circle)

while True:
    cv2.imshow("C:/Users/bobby/Downloads/Computer-Vision-with-Python/DATA/dog_backpack.jpg",img)
    
    if cv2.waitKey(20) & 0xFF == 27:
        break
        
cv2.destroyAllWindows()
